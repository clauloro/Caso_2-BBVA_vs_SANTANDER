# %% [markdown]
# # 2000-2025

# %%
import pandas as pd, requests, time
from datetime import datetime

START = "2000-01-01"
END   = "2025-10-31"

KW_BBVA = '( "BBVA" OR "Banco Bilbao Vizcaya Argentaria" OR BBVA.MC ) (sourcelang:es OR sourcelang:en)'
KW_SAN  = '( "Banco Santander" OR "Santander Group" OR SAN.MC ) (sourcelang:es OR sourcelang:en) NOT "provincia de Santander" NOT "Santander, Cantabria" NOT "Santander (Colombia)"'

KEYWORDS = [KW_BBVA, KW_SAN]

def week_chunks(start_date: str, end_date: str, step_days=7):
    s = pd.to_datetime(start_date); e = pd.to_datetime(end_date)
    cur = s
    out = []
    while cur <= e:
        end = min(cur + pd.Timedelta(days=step_days-1), e)
        out.append((cur, end))
        cur = end + pd.Timedelta(days=1)
    return out

def gdelt_query_window(keyword: str, start_dt: pd.Timestamp, end_dt: pd.Timestamp, maxrecords=250, tries=3):
    base = "https://api.gdeltproject.org/api/v2/doc/doc"
    s = start_dt.strftime("%Y%m%d%H%M%S")
    e = (end_dt + pd.Timedelta(hours=23, minutes=59, seconds=59)).strftime("%Y%m%d%H%M%S")
    params = {
        "query": keyword,
        "mode": "ArtList",
        "format": "json",
        "maxrecords": str(maxrecords),
        "sort": "DateDesc",
        "startdatetime": s,
        "enddatetime": e
    }
    for attempt in range(tries):
        try:
            r = requests.get(base, params=params, timeout=30)
            if r.status_code == 200:
                j = r.json()
                return j.get("articles", []) or []
            time.sleep(2**attempt)
        except Exception:
            time.sleep(2**attempt)
    return []

def collect_news_gdelt(keywords, start, end, step_days=7, sleep_s=0.25):
    chunks = week_chunks(start, end, step_days=step_days)
    all_rows = []
    for kw in keywords:
        for a,b in chunks:
            rows = gdelt_query_window(kw, a, b)
            if rows:
                for r in rows:
                    r["_kw"] = "BBVA" if kw == KEYWORDS[0] else "Santander"
                    all_rows.append(r)
            # log mínimo por ventana
            print(f"{kw[:25]}... {a.date()}→{b.date()} · {len(rows)} artículos")
            time.sleep(sleep_s)
    return pd.DataFrame.from_records(all_rows)

# %%
news_raw = collect_news_gdelt(KEYWORDS, START, END, step_days=7)
print("Shape:", news_raw.shape)
news_raw.head()
# Out:
# ( "BBVA" OR "Banco Bilbao... 2000-01-01→2000-01-07 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2000-01-08→2000-01-14 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2000-01-15→2000-01-21 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2000-01-22→2000-01-28 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2000-01-29→2000-02-04 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2000-02-05→2000-02-11 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2000-02-12→2000-02-18 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2000-02-19→2000-02-25 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2000-02-26→2000-03-03 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2000-03-04→2000-03-10 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2000-03-11→2000-03-17 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2000-03-18→2000-03-24 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2000-03-25→2000-03-31 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2000-04-01→2000-04-07 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2000-04-08→2000-04-14 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2000-04-15→2000-04-21 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2000-04-22→2000-04-28 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2000-04-29→2000-05-05 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2000-05-06→2000-05-12 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2000-05-13→2000-05-19 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2000-05-20→2000-05-26 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2000-05-27→2000-06-02 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2000-06-03→2000-06-09 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2000-06-10→2000-06-16 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2000-06-17→2000-06-23 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2000-06-24→2000-06-30 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2000-07-01→2000-07-07 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2000-07-08→2000-07-14 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2000-07-15→2000-07-21 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2000-07-22→2000-07-28 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2000-07-29→2000-08-04 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2000-08-05→2000-08-11 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2000-08-12→2000-08-18 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2000-08-19→2000-08-25 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2000-08-26→2000-09-01 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2000-09-02→2000-09-08 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2000-09-09→2000-09-15 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2000-09-16→2000-09-22 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2000-09-23→2000-09-29 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2000-09-30→2000-10-06 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2000-10-07→2000-10-13 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2000-10-14→2000-10-20 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2000-10-21→2000-10-27 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2000-10-28→2000-11-03 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2000-11-04→2000-11-10 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2000-11-11→2000-11-17 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2000-11-18→2000-11-24 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2000-11-25→2000-12-01 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2000-12-02→2000-12-08 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2000-12-09→2000-12-15 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2000-12-16→2000-12-22 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2000-12-23→2000-12-29 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2000-12-30→2001-01-05 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2001-01-06→2001-01-12 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2001-01-13→2001-01-19 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2001-01-20→2001-01-26 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2001-01-27→2001-02-02 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2001-02-03→2001-02-09 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2001-02-10→2001-02-16 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2001-02-17→2001-02-23 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2001-02-24→2001-03-02 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2001-03-03→2001-03-09 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2001-03-10→2001-03-16 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2001-03-17→2001-03-23 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2001-03-24→2001-03-30 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2001-03-31→2001-04-06 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2001-04-07→2001-04-13 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2001-04-14→2001-04-20 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2001-04-21→2001-04-27 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2001-04-28→2001-05-04 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2001-05-05→2001-05-11 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2001-05-12→2001-05-18 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2001-05-19→2001-05-25 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2001-05-26→2001-06-01 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2001-06-02→2001-06-08 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2001-06-09→2001-06-15 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2001-06-16→2001-06-22 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2001-06-23→2001-06-29 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2001-06-30→2001-07-06 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2001-07-07→2001-07-13 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2001-07-14→2001-07-20 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2001-07-21→2001-07-27 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2001-07-28→2001-08-03 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2001-08-04→2001-08-10 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2001-08-11→2001-08-17 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2001-08-18→2001-08-24 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2001-08-25→2001-08-31 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2001-09-01→2001-09-07 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2001-09-08→2001-09-14 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2001-09-15→2001-09-21 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2001-09-22→2001-09-28 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2001-09-29→2001-10-05 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2001-10-06→2001-10-12 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2001-10-13→2001-10-19 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2001-10-20→2001-10-26 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2001-10-27→2001-11-02 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2001-11-03→2001-11-09 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2001-11-10→2001-11-16 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2001-11-17→2001-11-23 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2001-11-24→2001-11-30 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2001-12-01→2001-12-07 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2001-12-08→2001-12-14 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2001-12-15→2001-12-21 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2001-12-22→2001-12-28 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2001-12-29→2002-01-04 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2002-01-05→2002-01-11 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2002-01-12→2002-01-18 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2002-01-19→2002-01-25 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2002-01-26→2002-02-01 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2002-02-02→2002-02-08 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2002-02-09→2002-02-15 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2002-02-16→2002-02-22 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2002-02-23→2002-03-01 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2002-03-02→2002-03-08 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2002-03-09→2002-03-15 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2002-03-16→2002-03-22 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2002-03-23→2002-03-29 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2002-03-30→2002-04-05 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2002-04-06→2002-04-12 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2002-04-13→2002-04-19 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2002-04-20→2002-04-26 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2002-04-27→2002-05-03 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2002-05-04→2002-05-10 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2002-05-11→2002-05-17 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2002-05-18→2002-05-24 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2002-05-25→2002-05-31 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2002-06-01→2002-06-07 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2002-06-08→2002-06-14 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2002-06-15→2002-06-21 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2002-06-22→2002-06-28 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2002-06-29→2002-07-05 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2002-07-06→2002-07-12 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2002-07-13→2002-07-19 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2002-07-20→2002-07-26 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2002-07-27→2002-08-02 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2002-08-03→2002-08-09 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2002-08-10→2002-08-16 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2002-08-17→2002-08-23 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2002-08-24→2002-08-30 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2002-08-31→2002-09-06 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2002-09-07→2002-09-13 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2002-09-14→2002-09-20 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2002-09-21→2002-09-27 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2002-09-28→2002-10-04 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2002-10-05→2002-10-11 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2002-10-12→2002-10-18 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2002-10-19→2002-10-25 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2002-10-26→2002-11-01 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2002-11-02→2002-11-08 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2002-11-09→2002-11-15 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2002-11-16→2002-11-22 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2002-11-23→2002-11-29 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2002-11-30→2002-12-06 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2002-12-07→2002-12-13 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2002-12-14→2002-12-20 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2002-12-21→2002-12-27 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2002-12-28→2003-01-03 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2003-01-04→2003-01-10 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2003-01-11→2003-01-17 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2003-01-18→2003-01-24 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2003-01-25→2003-01-31 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2003-02-01→2003-02-07 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2003-02-08→2003-02-14 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2003-02-15→2003-02-21 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2003-02-22→2003-02-28 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2003-03-01→2003-03-07 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2003-03-08→2003-03-14 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2003-03-15→2003-03-21 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2003-03-22→2003-03-28 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2003-03-29→2003-04-04 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2003-04-05→2003-04-11 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2003-04-12→2003-04-18 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2003-04-19→2003-04-25 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2003-04-26→2003-05-02 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2003-05-03→2003-05-09 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2003-05-10→2003-05-16 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2003-05-17→2003-05-23 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2003-05-24→2003-05-30 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2003-05-31→2003-06-06 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2003-06-07→2003-06-13 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2003-06-14→2003-06-20 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2003-06-21→2003-06-27 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2003-06-28→2003-07-04 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2003-07-05→2003-07-11 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2003-07-12→2003-07-18 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2003-07-19→2003-07-25 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2003-07-26→2003-08-01 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2003-08-02→2003-08-08 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2003-08-09→2003-08-15 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2003-08-16→2003-08-22 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2003-08-23→2003-08-29 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2003-08-30→2003-09-05 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2003-09-06→2003-09-12 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2003-09-13→2003-09-19 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2003-09-20→2003-09-26 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2003-09-27→2003-10-03 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2003-10-04→2003-10-10 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2003-10-11→2003-10-17 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2003-10-18→2003-10-24 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2003-10-25→2003-10-31 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2003-11-01→2003-11-07 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2003-11-08→2003-11-14 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2003-11-15→2003-11-21 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2003-11-22→2003-11-28 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2003-11-29→2003-12-05 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2003-12-06→2003-12-12 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2003-12-13→2003-12-19 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2003-12-20→2003-12-26 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2003-12-27→2004-01-02 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2004-01-03→2004-01-09 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2004-01-10→2004-01-16 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2004-01-17→2004-01-23 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2004-01-24→2004-01-30 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2004-01-31→2004-02-06 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2004-02-07→2004-02-13 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2004-02-14→2004-02-20 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2004-02-21→2004-02-27 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2004-02-28→2004-03-05 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2004-03-06→2004-03-12 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2004-03-13→2004-03-19 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2004-03-20→2004-03-26 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2004-03-27→2004-04-02 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2004-04-03→2004-04-09 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2004-04-10→2004-04-16 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2004-04-17→2004-04-23 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2004-04-24→2004-04-30 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2004-05-01→2004-05-07 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2004-05-08→2004-05-14 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2004-05-15→2004-05-21 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2004-05-22→2004-05-28 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2004-05-29→2004-06-04 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2004-06-05→2004-06-11 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2004-06-12→2004-06-18 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2004-06-19→2004-06-25 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2004-06-26→2004-07-02 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2004-07-03→2004-07-09 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2004-07-10→2004-07-16 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2004-07-17→2004-07-23 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2004-07-24→2004-07-30 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2004-07-31→2004-08-06 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2004-08-07→2004-08-13 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2004-08-14→2004-08-20 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2004-08-21→2004-08-27 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2004-08-28→2004-09-03 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2004-09-04→2004-09-10 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2004-09-11→2004-09-17 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2004-09-18→2004-09-24 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2004-09-25→2004-10-01 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2004-10-02→2004-10-08 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2004-10-09→2004-10-15 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2004-10-16→2004-10-22 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2004-10-23→2004-10-29 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2004-10-30→2004-11-05 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2004-11-06→2004-11-12 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2004-11-13→2004-11-19 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2004-11-20→2004-11-26 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2004-11-27→2004-12-03 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2004-12-04→2004-12-10 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2004-12-11→2004-12-17 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2004-12-18→2004-12-24 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2004-12-25→2004-12-31 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2005-01-01→2005-01-07 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2005-01-08→2005-01-14 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2005-01-15→2005-01-21 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2005-01-22→2005-01-28 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2005-01-29→2005-02-04 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2005-02-05→2005-02-11 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2005-02-12→2005-02-18 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2005-02-19→2005-02-25 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2005-02-26→2005-03-04 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2005-03-05→2005-03-11 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2005-03-12→2005-03-18 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2005-03-19→2005-03-25 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2005-03-26→2005-04-01 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2005-04-02→2005-04-08 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2005-04-09→2005-04-15 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2005-04-16→2005-04-22 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2005-04-23→2005-04-29 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2005-04-30→2005-05-06 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2005-05-07→2005-05-13 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2005-05-14→2005-05-20 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2005-05-21→2005-05-27 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2005-05-28→2005-06-03 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2005-06-04→2005-06-10 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2005-06-11→2005-06-17 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2005-06-18→2005-06-24 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2005-06-25→2005-07-01 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2005-07-02→2005-07-08 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2005-07-09→2005-07-15 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2005-07-16→2005-07-22 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2005-07-23→2005-07-29 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2005-07-30→2005-08-05 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2005-08-06→2005-08-12 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2005-08-13→2005-08-19 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2005-08-20→2005-08-26 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2005-08-27→2005-09-02 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2005-09-03→2005-09-09 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2005-09-10→2005-09-16 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2005-09-17→2005-09-23 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2005-09-24→2005-09-30 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2005-10-01→2005-10-07 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2005-10-08→2005-10-14 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2005-10-15→2005-10-21 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2005-10-22→2005-10-28 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2005-10-29→2005-11-04 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2005-11-05→2005-11-11 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2005-11-12→2005-11-18 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2005-11-19→2005-11-25 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2005-11-26→2005-12-02 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2005-12-03→2005-12-09 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2005-12-10→2005-12-16 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2005-12-17→2005-12-23 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2005-12-24→2005-12-30 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2005-12-31→2006-01-06 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2006-01-07→2006-01-13 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2006-01-14→2006-01-20 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2006-01-21→2006-01-27 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2006-01-28→2006-02-03 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2006-02-04→2006-02-10 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2006-02-11→2006-02-17 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2006-02-18→2006-02-24 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2006-02-25→2006-03-03 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2006-03-04→2006-03-10 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2006-03-11→2006-03-17 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2006-03-18→2006-03-24 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2006-03-25→2006-03-31 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2006-04-01→2006-04-07 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2006-04-08→2006-04-14 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2006-04-15→2006-04-21 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2006-04-22→2006-04-28 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2006-04-29→2006-05-05 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2006-05-06→2006-05-12 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2006-05-13→2006-05-19 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2006-05-20→2006-05-26 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2006-05-27→2006-06-02 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2006-06-03→2006-06-09 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2006-06-10→2006-06-16 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2006-06-17→2006-06-23 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2006-06-24→2006-06-30 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2006-07-01→2006-07-07 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2006-07-08→2006-07-14 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2006-07-15→2006-07-21 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2006-07-22→2006-07-28 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2006-07-29→2006-08-04 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2006-08-05→2006-08-11 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2006-08-12→2006-08-18 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2006-08-19→2006-08-25 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2006-08-26→2006-09-01 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2006-09-02→2006-09-08 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2006-09-09→2006-09-15 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2006-09-16→2006-09-22 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2006-09-23→2006-09-29 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2006-09-30→2006-10-06 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2006-10-07→2006-10-13 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2006-10-14→2006-10-20 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2006-10-21→2006-10-27 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2006-10-28→2006-11-03 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2006-11-04→2006-11-10 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2006-11-11→2006-11-17 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2006-11-18→2006-11-24 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2006-11-25→2006-12-01 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2006-12-02→2006-12-08 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2006-12-09→2006-12-15 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2006-12-16→2006-12-22 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2006-12-23→2006-12-29 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2006-12-30→2007-01-05 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2007-01-06→2007-01-12 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2007-01-13→2007-01-19 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2007-01-20→2007-01-26 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2007-01-27→2007-02-02 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2007-02-03→2007-02-09 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2007-02-10→2007-02-16 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2007-02-17→2007-02-23 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2007-02-24→2007-03-02 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2007-03-03→2007-03-09 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2007-03-10→2007-03-16 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2007-03-17→2007-03-23 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2007-03-24→2007-03-30 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2007-03-31→2007-04-06 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2007-04-07→2007-04-13 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2007-04-14→2007-04-20 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2007-04-21→2007-04-27 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2007-04-28→2007-05-04 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2007-05-05→2007-05-11 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2007-05-12→2007-05-18 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2007-05-19→2007-05-25 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2007-05-26→2007-06-01 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2007-06-02→2007-06-08 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2007-06-09→2007-06-15 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2007-06-16→2007-06-22 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2007-06-23→2007-06-29 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2007-06-30→2007-07-06 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2007-07-07→2007-07-13 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2007-07-14→2007-07-20 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2007-07-21→2007-07-27 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2007-07-28→2007-08-03 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2007-08-04→2007-08-10 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2007-08-11→2007-08-17 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2007-08-18→2007-08-24 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2007-08-25→2007-08-31 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2007-09-01→2007-09-07 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2007-09-08→2007-09-14 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2007-09-15→2007-09-21 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2007-09-22→2007-09-28 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2007-09-29→2007-10-05 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2007-10-06→2007-10-12 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2007-10-13→2007-10-19 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2007-10-20→2007-10-26 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2007-10-27→2007-11-02 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2007-11-03→2007-11-09 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2007-11-10→2007-11-16 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2007-11-17→2007-11-23 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2007-11-24→2007-11-30 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2007-12-01→2007-12-07 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2007-12-08→2007-12-14 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2007-12-15→2007-12-21 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2007-12-22→2007-12-28 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2007-12-29→2008-01-04 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2008-01-05→2008-01-11 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2008-01-12→2008-01-18 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2008-01-19→2008-01-25 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2008-01-26→2008-02-01 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2008-02-02→2008-02-08 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2008-02-09→2008-02-15 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2008-02-16→2008-02-22 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2008-02-23→2008-02-29 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2008-03-01→2008-03-07 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2008-03-08→2008-03-14 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2008-03-15→2008-03-21 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2008-03-22→2008-03-28 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2008-03-29→2008-04-04 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2008-04-05→2008-04-11 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2008-04-12→2008-04-18 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2008-04-19→2008-04-25 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2008-04-26→2008-05-02 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2008-05-03→2008-05-09 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2008-05-10→2008-05-16 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2008-05-17→2008-05-23 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2008-05-24→2008-05-30 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2008-05-31→2008-06-06 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2008-06-07→2008-06-13 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2008-06-14→2008-06-20 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2008-06-21→2008-06-27 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2008-06-28→2008-07-04 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2008-07-05→2008-07-11 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2008-07-12→2008-07-18 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2008-07-19→2008-07-25 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2008-07-26→2008-08-01 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2008-08-02→2008-08-08 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2008-08-09→2008-08-15 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2008-08-16→2008-08-22 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2008-08-23→2008-08-29 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2008-08-30→2008-09-05 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2008-09-06→2008-09-12 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2008-09-13→2008-09-19 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2008-09-20→2008-09-26 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2008-09-27→2008-10-03 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2008-10-04→2008-10-10 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2008-10-11→2008-10-17 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2008-10-18→2008-10-24 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2008-10-25→2008-10-31 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2008-11-01→2008-11-07 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2008-11-08→2008-11-14 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2008-11-15→2008-11-21 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2008-11-22→2008-11-28 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2008-11-29→2008-12-05 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2008-12-06→2008-12-12 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2008-12-13→2008-12-19 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2008-12-20→2008-12-26 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2008-12-27→2009-01-02 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2009-01-03→2009-01-09 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2009-01-10→2009-01-16 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2009-01-17→2009-01-23 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2009-01-24→2009-01-30 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2009-01-31→2009-02-06 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2009-02-07→2009-02-13 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2009-02-14→2009-02-20 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2009-02-21→2009-02-27 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2009-02-28→2009-03-06 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2009-03-07→2009-03-13 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2009-03-14→2009-03-20 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2009-03-21→2009-03-27 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2009-03-28→2009-04-03 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2009-04-04→2009-04-10 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2009-04-11→2009-04-17 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2009-04-18→2009-04-24 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2009-04-25→2009-05-01 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2009-05-02→2009-05-08 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2009-05-09→2009-05-15 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2009-05-16→2009-05-22 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2009-05-23→2009-05-29 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2009-05-30→2009-06-05 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2009-06-06→2009-06-12 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2009-06-13→2009-06-19 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2009-06-20→2009-06-26 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2009-06-27→2009-07-03 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2009-07-04→2009-07-10 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2009-07-11→2009-07-17 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2009-07-18→2009-07-24 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2009-07-25→2009-07-31 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2009-08-01→2009-08-07 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2009-08-08→2009-08-14 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2009-08-15→2009-08-21 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2009-08-22→2009-08-28 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2009-08-29→2009-09-04 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2009-09-05→2009-09-11 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2009-09-12→2009-09-18 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2009-09-19→2009-09-25 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2009-09-26→2009-10-02 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2009-10-03→2009-10-09 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2009-10-10→2009-10-16 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2009-10-17→2009-10-23 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2009-10-24→2009-10-30 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2009-10-31→2009-11-06 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2009-11-07→2009-11-13 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2009-11-14→2009-11-20 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2009-11-21→2009-11-27 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2009-11-28→2009-12-04 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2009-12-05→2009-12-11 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2009-12-12→2009-12-18 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2009-12-19→2009-12-25 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2009-12-26→2010-01-01 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2010-01-02→2010-01-08 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2010-01-09→2010-01-15 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2010-01-16→2010-01-22 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2010-01-23→2010-01-29 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2010-01-30→2010-02-05 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2010-02-06→2010-02-12 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2010-02-13→2010-02-19 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2010-02-20→2010-02-26 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2010-02-27→2010-03-05 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2010-03-06→2010-03-12 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2010-03-13→2010-03-19 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2010-03-20→2010-03-26 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2010-03-27→2010-04-02 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2010-04-03→2010-04-09 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2010-04-10→2010-04-16 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2010-04-17→2010-04-23 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2010-04-24→2010-04-30 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2010-05-01→2010-05-07 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2010-05-08→2010-05-14 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2010-05-15→2010-05-21 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2010-05-22→2010-05-28 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2010-05-29→2010-06-04 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2010-06-05→2010-06-11 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2010-06-12→2010-06-18 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2010-06-19→2010-06-25 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2010-06-26→2010-07-02 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2010-07-03→2010-07-09 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2010-07-10→2010-07-16 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2010-07-17→2010-07-23 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2010-07-24→2010-07-30 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2010-07-31→2010-08-06 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2010-08-07→2010-08-13 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2010-08-14→2010-08-20 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2010-08-21→2010-08-27 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2010-08-28→2010-09-03 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2010-09-04→2010-09-10 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2010-09-11→2010-09-17 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2010-09-18→2010-09-24 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2010-09-25→2010-10-01 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2010-10-02→2010-10-08 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2010-10-09→2010-10-15 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2010-10-16→2010-10-22 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2010-10-23→2010-10-29 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2010-10-30→2010-11-05 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2010-11-06→2010-11-12 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2010-11-13→2010-11-19 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2010-11-20→2010-11-26 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2010-11-27→2010-12-03 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2010-12-04→2010-12-10 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2010-12-11→2010-12-17 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2010-12-18→2010-12-24 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2010-12-25→2010-12-31 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2011-01-01→2011-01-07 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2011-01-08→2011-01-14 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2011-01-15→2011-01-21 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2011-01-22→2011-01-28 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2011-01-29→2011-02-04 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2011-02-05→2011-02-11 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2011-02-12→2011-02-18 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2011-02-19→2011-02-25 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2011-02-26→2011-03-04 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2011-03-05→2011-03-11 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2011-03-12→2011-03-18 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2011-03-19→2011-03-25 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2011-03-26→2011-04-01 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2011-04-02→2011-04-08 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2011-04-09→2011-04-15 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2011-04-16→2011-04-22 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2011-04-23→2011-04-29 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2011-04-30→2011-05-06 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2011-05-07→2011-05-13 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2011-05-14→2011-05-20 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2011-05-21→2011-05-27 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2011-05-28→2011-06-03 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2011-06-04→2011-06-10 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2011-06-11→2011-06-17 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2011-06-18→2011-06-24 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2011-06-25→2011-07-01 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2011-07-02→2011-07-08 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2011-07-09→2011-07-15 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2011-07-16→2011-07-22 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2011-07-23→2011-07-29 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2011-07-30→2011-08-05 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2011-08-06→2011-08-12 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2011-08-13→2011-08-19 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2011-08-20→2011-08-26 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2011-08-27→2011-09-02 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2011-09-03→2011-09-09 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2011-09-10→2011-09-16 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2011-09-17→2011-09-23 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2011-09-24→2011-09-30 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2011-10-01→2011-10-07 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2011-10-08→2011-10-14 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2011-10-15→2011-10-21 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2011-10-22→2011-10-28 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2011-10-29→2011-11-04 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2011-11-05→2011-11-11 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2011-11-12→2011-11-18 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2011-11-19→2011-11-25 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2011-11-26→2011-12-02 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2011-12-03→2011-12-09 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2011-12-10→2011-12-16 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2011-12-17→2011-12-23 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2011-12-24→2011-12-30 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2011-12-31→2012-01-06 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2012-01-07→2012-01-13 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2012-01-14→2012-01-20 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2012-01-21→2012-01-27 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2012-01-28→2012-02-03 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2012-02-04→2012-02-10 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2012-02-11→2012-02-17 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2012-02-18→2012-02-24 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2012-02-25→2012-03-02 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2012-03-03→2012-03-09 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2012-03-10→2012-03-16 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2012-03-17→2012-03-23 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2012-03-24→2012-03-30 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2012-03-31→2012-04-06 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2012-04-07→2012-04-13 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2012-04-14→2012-04-20 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2012-04-21→2012-04-27 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2012-04-28→2012-05-04 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2012-05-05→2012-05-11 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2012-05-12→2012-05-18 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2012-05-19→2012-05-25 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2012-05-26→2012-06-01 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2012-06-02→2012-06-08 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2012-06-09→2012-06-15 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2012-06-16→2012-06-22 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2012-06-23→2012-06-29 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2012-06-30→2012-07-06 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2012-07-07→2012-07-13 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2012-07-14→2012-07-20 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2012-07-21→2012-07-27 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2012-07-28→2012-08-03 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2012-08-04→2012-08-10 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2012-08-11→2012-08-17 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2012-08-18→2012-08-24 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2012-08-25→2012-08-31 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2012-09-01→2012-09-07 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2012-09-08→2012-09-14 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2012-09-15→2012-09-21 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2012-09-22→2012-09-28 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2012-09-29→2012-10-05 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2012-10-06→2012-10-12 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2012-10-13→2012-10-19 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2012-10-20→2012-10-26 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2012-10-27→2012-11-02 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2012-11-03→2012-11-09 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2012-11-10→2012-11-16 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2012-11-17→2012-11-23 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2012-11-24→2012-11-30 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2012-12-01→2012-12-07 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2012-12-08→2012-12-14 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2012-12-15→2012-12-21 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2012-12-22→2012-12-28 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2012-12-29→2013-01-04 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2013-01-05→2013-01-11 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2013-01-12→2013-01-18 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2013-01-19→2013-01-25 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2013-01-26→2013-02-01 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2013-02-02→2013-02-08 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2013-02-09→2013-02-15 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2013-02-16→2013-02-22 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2013-02-23→2013-03-01 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2013-03-02→2013-03-08 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2013-03-09→2013-03-15 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2013-03-16→2013-03-22 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2013-03-23→2013-03-29 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2013-03-30→2013-04-05 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2013-04-06→2013-04-12 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2013-04-13→2013-04-19 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2013-04-20→2013-04-26 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2013-04-27→2013-05-03 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2013-05-04→2013-05-10 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2013-05-11→2013-05-17 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2013-05-18→2013-05-24 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2013-05-25→2013-05-31 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2013-06-01→2013-06-07 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2013-06-08→2013-06-14 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2013-06-15→2013-06-21 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2013-06-22→2013-06-28 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2013-06-29→2013-07-05 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2013-07-06→2013-07-12 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2013-07-13→2013-07-19 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2013-07-20→2013-07-26 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2013-07-27→2013-08-02 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2013-08-03→2013-08-09 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2013-08-10→2013-08-16 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2013-08-17→2013-08-23 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2013-08-24→2013-08-30 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2013-08-31→2013-09-06 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2013-09-07→2013-09-13 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2013-09-14→2013-09-20 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2013-09-21→2013-09-27 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2013-09-28→2013-10-04 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2013-10-05→2013-10-11 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2013-10-12→2013-10-18 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2013-10-19→2013-10-25 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2013-10-26→2013-11-01 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2013-11-02→2013-11-08 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2013-11-09→2013-11-15 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2013-11-16→2013-11-22 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2013-11-23→2013-11-29 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2013-11-30→2013-12-06 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2013-12-07→2013-12-13 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2013-12-14→2013-12-20 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2013-12-21→2013-12-27 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2013-12-28→2014-01-03 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2014-01-04→2014-01-10 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2014-01-11→2014-01-17 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2014-01-18→2014-01-24 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2014-01-25→2014-01-31 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2014-02-01→2014-02-07 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2014-02-08→2014-02-14 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2014-02-15→2014-02-21 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2014-02-22→2014-02-28 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2014-03-01→2014-03-07 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2014-03-08→2014-03-14 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2014-03-15→2014-03-21 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2014-03-22→2014-03-28 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2014-03-29→2014-04-04 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2014-04-05→2014-04-11 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2014-04-12→2014-04-18 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2014-04-19→2014-04-25 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2014-04-26→2014-05-02 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2014-05-03→2014-05-09 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2014-05-10→2014-05-16 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2014-05-17→2014-05-23 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2014-05-24→2014-05-30 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2014-05-31→2014-06-06 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2014-06-07→2014-06-13 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2014-06-14→2014-06-20 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2014-06-21→2014-06-27 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2014-06-28→2014-07-04 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2014-07-05→2014-07-11 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2014-07-12→2014-07-18 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2014-07-19→2014-07-25 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2014-07-26→2014-08-01 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2014-08-02→2014-08-08 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2014-08-09→2014-08-15 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2014-08-16→2014-08-22 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2014-08-23→2014-08-29 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2014-08-30→2014-09-05 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2014-09-06→2014-09-12 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2014-09-13→2014-09-19 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2014-09-20→2014-09-26 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2014-09-27→2014-10-03 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2014-10-04→2014-10-10 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2014-10-11→2014-10-17 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2014-10-18→2014-10-24 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2014-10-25→2014-10-31 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2014-11-01→2014-11-07 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2014-11-08→2014-11-14 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2014-11-15→2014-11-21 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2014-11-22→2014-11-28 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2014-11-29→2014-12-05 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2014-12-06→2014-12-12 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2014-12-13→2014-12-19 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2014-12-20→2014-12-26 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2014-12-27→2015-01-02 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2015-01-03→2015-01-09 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2015-01-10→2015-01-16 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2015-01-17→2015-01-23 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2015-01-24→2015-01-30 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2015-01-31→2015-02-06 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2015-02-07→2015-02-13 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2015-02-14→2015-02-20 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2015-02-21→2015-02-27 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2015-02-28→2015-03-06 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2015-03-07→2015-03-13 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2015-03-14→2015-03-20 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2015-03-21→2015-03-27 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2015-03-28→2015-04-03 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2015-04-04→2015-04-10 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2015-04-11→2015-04-17 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2015-04-18→2015-04-24 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2015-04-25→2015-05-01 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2015-05-02→2015-05-08 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2015-05-09→2015-05-15 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2015-05-16→2015-05-22 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2015-05-23→2015-05-29 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2015-05-30→2015-06-05 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2015-06-06→2015-06-12 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2015-06-13→2015-06-19 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2015-06-20→2015-06-26 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2015-06-27→2015-07-03 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2015-07-04→2015-07-10 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2015-07-11→2015-07-17 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2015-07-18→2015-07-24 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2015-07-25→2015-07-31 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2015-08-01→2015-08-07 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2015-08-08→2015-08-14 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2015-08-15→2015-08-21 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2015-08-22→2015-08-28 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2015-08-29→2015-09-04 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2015-09-05→2015-09-11 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2015-09-12→2015-09-18 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2015-09-19→2015-09-25 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2015-09-26→2015-10-02 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2015-10-03→2015-10-09 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2015-10-10→2015-10-16 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2015-10-17→2015-10-23 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2015-10-24→2015-10-30 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2015-10-31→2015-11-06 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2015-11-07→2015-11-13 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2015-11-14→2015-11-20 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2015-11-21→2015-11-27 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2015-11-28→2015-12-04 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2015-12-05→2015-12-11 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2015-12-12→2015-12-18 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2015-12-19→2015-12-25 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2015-12-26→2016-01-01 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2016-01-02→2016-01-08 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2016-01-09→2016-01-15 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2016-01-16→2016-01-22 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2016-01-23→2016-01-29 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2016-01-30→2016-02-05 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2016-02-06→2016-02-12 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2016-02-13→2016-02-19 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2016-02-20→2016-02-26 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2016-02-27→2016-03-04 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2016-03-05→2016-03-11 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2016-03-12→2016-03-18 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2016-03-19→2016-03-25 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2016-03-26→2016-04-01 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2016-04-02→2016-04-08 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2016-04-09→2016-04-15 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2016-04-16→2016-04-22 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2016-04-23→2016-04-29 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2016-04-30→2016-05-06 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2016-05-07→2016-05-13 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2016-05-14→2016-05-20 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2016-05-21→2016-05-27 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2016-05-28→2016-06-03 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2016-06-04→2016-06-10 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2016-06-11→2016-06-17 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2016-06-18→2016-06-24 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2016-06-25→2016-07-01 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2016-07-02→2016-07-08 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2016-07-09→2016-07-15 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2016-07-16→2016-07-22 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2016-07-23→2016-07-29 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2016-07-30→2016-08-05 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2016-08-06→2016-08-12 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2016-08-13→2016-08-19 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2016-08-20→2016-08-26 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2016-08-27→2016-09-02 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2016-09-03→2016-09-09 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2016-09-10→2016-09-16 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2016-09-17→2016-09-23 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2016-09-24→2016-09-30 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2016-10-01→2016-10-07 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2016-10-08→2016-10-14 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2016-10-15→2016-10-21 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2016-10-22→2016-10-28 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2016-10-29→2016-11-04 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2016-11-05→2016-11-11 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2016-11-12→2016-11-18 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2016-11-19→2016-11-25 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2016-11-26→2016-12-02 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2016-12-03→2016-12-09 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2016-12-10→2016-12-16 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2016-12-17→2016-12-23 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2016-12-24→2016-12-30 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2016-12-31→2017-01-06 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2017-01-07→2017-01-13 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2017-01-14→2017-01-20 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2017-01-21→2017-01-27 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2017-01-28→2017-02-03 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2017-02-04→2017-02-10 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2017-02-11→2017-02-17 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2017-02-18→2017-02-24 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2017-02-25→2017-03-03 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2017-03-04→2017-03-10 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2017-03-11→2017-03-17 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2017-03-18→2017-03-24 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2017-03-25→2017-03-31 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2017-04-01→2017-04-07 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2017-04-08→2017-04-14 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2017-04-15→2017-04-21 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2017-04-22→2017-04-28 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2017-04-29→2017-05-05 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2017-05-06→2017-05-12 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2017-05-13→2017-05-19 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2017-05-20→2017-05-26 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2017-05-27→2017-06-02 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2017-06-03→2017-06-09 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2017-06-10→2017-06-16 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2017-06-17→2017-06-23 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2017-06-24→2017-06-30 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2017-07-01→2017-07-07 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2017-07-08→2017-07-14 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2017-07-15→2017-07-21 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2017-07-22→2017-07-28 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2017-07-29→2017-08-04 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2017-08-05→2017-08-11 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2017-08-12→2017-08-18 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2017-08-19→2017-08-25 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2017-08-26→2017-09-01 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2017-09-02→2017-09-08 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2017-09-09→2017-09-15 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2017-09-16→2017-09-22 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2017-09-23→2017-09-29 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2017-09-30→2017-10-06 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2017-10-07→2017-10-13 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2017-10-14→2017-10-20 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2017-10-21→2017-10-27 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2017-10-28→2017-11-03 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2017-11-04→2017-11-10 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2017-11-11→2017-11-17 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2017-11-18→2017-11-24 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2017-11-25→2017-12-01 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2017-12-02→2017-12-08 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2017-12-09→2017-12-15 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2017-12-16→2017-12-22 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2017-12-23→2017-12-29 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2017-12-30→2018-01-05 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2018-01-06→2018-01-12 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2018-01-13→2018-01-19 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2018-01-20→2018-01-26 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2018-01-27→2018-02-02 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2018-02-03→2018-02-09 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2018-02-10→2018-02-16 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2018-02-17→2018-02-23 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2018-02-24→2018-03-02 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2018-03-03→2018-03-09 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2018-03-10→2018-03-16 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2018-03-17→2018-03-23 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2018-03-24→2018-03-30 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2018-03-31→2018-04-06 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2018-04-07→2018-04-13 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2018-04-14→2018-04-20 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2018-04-21→2018-04-27 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2018-04-28→2018-05-04 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2018-05-05→2018-05-11 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2018-05-12→2018-05-18 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2018-05-19→2018-05-25 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2018-05-26→2018-06-01 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2018-06-02→2018-06-08 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2018-06-09→2018-06-15 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2018-06-16→2018-06-22 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2018-06-23→2018-06-29 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2018-06-30→2018-07-06 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2018-07-07→2018-07-13 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2018-07-14→2018-07-20 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2018-07-21→2018-07-27 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2018-07-28→2018-08-03 · 0 artículos
# ( "BBVA" OR "Banco Bilbao... 2018-08-04→2018-08-10 · 0 artículos

# %%
def normalize_gdelt(df: pd.DataFrame) -> pd.DataFrame:
    if df.empty:
        return df.copy()

    df = df.copy()
    # fecha
    if "seendate" in df.columns:
        def parse_see(x):
            try: return pd.to_datetime(x, format="%Y%m%d%H%M%S", errors="coerce")
            except: return pd.to_datetime(x, errors="coerce")
        df["dt"] = df["seendate"].apply(parse_see)
    elif "date" in df.columns:
        df["dt"] = pd.to_datetime(df["date"], errors="coerce")
    else:
        df["dt"] = pd.NaT

    # columnas mínimas
    for c in ["title","url","domain","sourcecountry","language"]:
        if c not in df.columns: df[c] = None

    out = df.rename(columns={"sourcecountry":"source_country"})[
        ["dt","language","source_country","domain","title","url","_kw"]
    ].dropna(subset=["dt"]).sort_values("dt").reset_index(drop=True)

    # dedup básicos
    out = out.drop_duplicates(subset=["url"])
    out = out.drop_duplicates(subset=["title","dt"])
    return out

news_norm = normalize_gdelt(news_raw)
print("Después de normalize:", news_norm.shape)
news_norm.head()

# %%
test = gdelt_query_window(KEYWORDS[0], pd.to_datetime("2024-01-01"), pd.to_datetime("2024-01-07"))
print(len(test))
test[:1]

# %% [markdown]
# ---

# %%
def daterange_chunks(start_date: str, end_date: str, freq="Q"):
    # genera [("2000-01-01","2000-03-31"), ("2000-04-01","2000-06-30"), ...]
    s = pd.to_datetime(start_date)
    e = pd.to_datetime(end_date)
    edges = pd.date_range(s, e, freq=freq).to_list()
    if not edges or edges[-1] < e:
        edges.append(e)
    # construir intervalos consecutivos
    chunks = []
    cur = s
    for edge in edges:
        if edge < cur: 
            continue
        chunk_end = min(edge, e)
        chunks.append((cur, chunk_end))
        cur = edge + pd.Timedelta(days=1)
        if cur > e:
            break
    return chunks

def gdelt_query(keyword: str, start_dt: pd.Timestamp, end_dt: pd.Timestamp, max_per_chunk=250):
    """
    Usa el endpoint Doc 2.1 (ArtList). Devuelve lista de artículos (dicts).
    GDELT limita 250 por request. Iteramos con sort=DateDesc y 'timespan' indirecto.
    """
    base = "https://api.gdeltproject.org/api/v2/doc/doc"
    # Formato timestamps: YYYYMMDDHHMMSS
    s = start_dt.strftime("%Y%m%d%H%M%S")
    e = (end_dt + pd.Timedelta(hours=23, minutes=59, seconds=59)).strftime("%Y%m%d%H%M%S")

    params = {
        "query": keyword,
        "mode": "ArtList",
        "format": "json",
        "maxrecords": str(max_per_chunk),
        "sort": "DateDesc",
        "startdatetime": s,
        "enddatetime": e
    }

    all_rows = []
    # Intentos con backoff por si hay throttling
    for attempt in range(3):
        try:
            r = requests.get(base, params=params, timeout=30)
            if r.status_code == 200:
                data = r.json()
                rows = data.get("articles", [])
                all_rows.extend(rows)
                break
            else:
                time.sleep(2**attempt)
        except Exception:
            time.sleep(2**attempt)
    return all_rows

def collect_news_gdelt(keywords, start, end, freq="Q", sleep_s=0.5):
    chunks = daterange_chunks(start, end, freq=freq)
    records = []
    for kw in keywords:
        for (a,b) in tqdm(chunks, desc=f"Descargando: {kw}"):
            rows = gdelt_query(kw, a, b)
            for r in rows:
                r["_kw"] = kw
                records.append(r)
            time.sleep(sleep_s)  # cortesía
    return pd.DataFrame.from_records(records)

news_raw = collect_news_gdelt(KEYWORDS, START, END, freq="Q")
print(news_raw.shape)
news_raw.head()
# Out:
# C:\Users\lopec\AppData\Local\Temp\ipykernel_41636\2901136136.py:5: FutureWarning: 'Q' is deprecated and will be removed in a future version, please use 'QE' instead.
#   edges = pd.date_range(s, e, freq=freq).to_list()
# Descargando: "BBVA" OR "Banco Bilbao Vizcaya Argentaria" OR BBVA.MC: 100%|██████████| 104/104 [19:14<00:00, 11.10s/it]
# Descargando: "Banco Santander" OR "Santander" OR SAN.MC: 100%|██████████| 104/104 [19:30<00:00, 11.25s/it]
# (0, 0)
# Empty DataFrame
# Columns: []
# Index: []

# %%
raw_path = RAW_NEWS_DIR / "gdelt_bbva_santander_2000_2025.parquet"
news_raw.to_parquet(raw_path, index=False)
raw_path

# %%
def normalize_gdelt(df: pd.DataFrame) -> pd.DataFrame:
    if df.empty:
        return df

    # columnas típicas: date, url, title, language, sourceCountry, domain, etc.
    df = df.copy()

    # fecha a datetime (GDELT da epochms o string dependiendo del caso)
    if "seendate" in df.columns:
        # algunos endpoints devuelven "seendate" como "YYYYMMDDHHMMSS"
        def parse_see(x):
            try:
                return pd.to_datetime(x, format="%Y%m%d%H%M%S", errors="coerce")
            except Exception:
                return pd.to_datetime(x, errors="coerce")
        df["dt"] = df["seendate"].apply(parse_see)
    elif "date" in df.columns:
        df["dt"] = pd.to_datetime(df["date"], errors="coerce")
    else:
        df["dt"] = pd.NaT

    # filtrar idiomas
    lang_col = "language" if "language" in df.columns else None
    if lang_col:
        df["language"] = df[lang_col].str.lower().fillna("")
        df = df[df["language"].isin(["spanish", "english"])]

    # renombrar campos
    rename_map = {
        "title": "title",
        "url": "url",
        "domain": "domain",
        "sourcecountry": "source_country",
    }
    # asegurar columnas
    for c in ["title","url","domain","sourcecountry"]:
        if c not in df.columns:
            df[c] = None

    out = df.rename(columns=rename_map)[["dt","language","source_country","domain","title","url","_kw"]].copy()
    out = out.dropna(subset=["dt"]).sort_values("dt").reset_index(drop=True)

    # deduplicados básicos
    out = out.drop_duplicates(subset=["url"]).drop_duplicates(subset=["title","dt"])
    return out

news_norm = normalize_gdelt(news_raw)
news_norm.shape, news_norm.head()

# %%
norm_path = INT_NEWS_DIR / "news_norm_2000_2025.parquet"
news_norm.to_parquet(norm_path, index=False)
norm_path

# %%
import re
from urllib.parse import urlparse

def simple_fetch_text(url, timeout=12):
    try:
        r = requests.get(url, timeout=timeout, headers={"User-Agent": "Mozilla/5.0"})
        if r.status_code!=200: 
            return None
        # extracción muy básica del <title> y párrafos
        html = r.text
        # cortar scripts/style
        html = re.sub(r"<script.*?</script>", " ", html, flags=re.S|re.I)
        html = re.sub(r"<style.*?</style>", " ", html, flags=re.S|re.I)
        # tags -> espacios
        text = re.sub(r"<[^>]+>", " ", html)
        # normalización básica
        text = re.sub(r"\s+", " ", text).strip()
        return text[:50000]  # limitar
    except:
        return None

# Pequeña muestra para probar:
sample = news_norm.head(50).copy()
sample["raw_text"] = sample["url"].apply(simple_fetch_text)
sample.head(2)

# %%
# Sentimiento con pysentimiento (español)
from pysentimiento import create_analyzer

# Cargar una vez (puede tardar un poco en la primera)
analyzer = create_analyzer(task="sentiment", lang="es")

def infer_sentiment(text: str, lang: str):
    """
    Si lang es 'spanish' -> usamos analyzer ES
    Si lang es 'english' -> también probamos con ES (multilingüe suele aguantar)
    Mejoras: añadir segundo analyzer en inglés si vemos mucho contenido EN.
    """
    if not isinstance(text, str) or len(text.strip()) == 0:
        return None, None
    # Recortar para velocidad (los titulares + primeros 500-1000 chars suelen bastar)
    chunk = text[:1200]
    res = analyzer.predict(chunk)
    label = res.output  # POS/NEG/NEU
    score = res.probas.get(label, None)
    return label, score

# Para empezar, usaremos el TITLE como entrada (rápido).
news_for_sent = news_norm.copy()
news_for_sent["text_base"] = news_for_sent["title"].fillna("")

# Inferencia por lotes (titulares)
sent_labels, sent_scores = [], []
for t, lang in tqdm(zip(news_for_sent["text_base"], news_for_sent["language"]), total=len(news_for_sent)):
    lab, sco = infer_sentiment(t, lang)
    sent_labels.append(lab); sent_scores.append(sco)

news_for_sent["sent_label"] = sent_labels
news_for_sent["sent_score"] = sent_scores

news_for_sent.head()

# %%
sent_titles_path = INT_NEWS_DIR / "news_sent_titles.parquet"
news_for_sent.to_parquet(sent_titles_path, index=False)
sent_titles_path

# %%
df = news_for_sent.copy()
df["date"] = df["dt"].dt.date

# Mapear a score numérico sencillo
map_num = {"POS": 1, "NEU": 0, "NEG": -1, None: 0}
df["sent_num"] = df["sent_label"].map(map_num).fillna(0)

agg_daily = (df
             .groupby(["date","_kw"])
             .agg(n=("url","count"),
                  pos=("sent_label", lambda s: (s=="POS").sum()),
                  neg=("sent_label", lambda s: (s=="NEG").sum()),
                  neu=("sent_label", lambda s: (s=="NEU").sum()),
                  sent_mean=("sent_num","mean"))
             .reset_index())

# Pivot para tener BBVA y SAN en columnas
pivot_cols = ["n","pos","neg","neu","sent_mean"]
out_daily = (agg_daily
             .pivot(index="date", columns="_kw", values=pivot_cols)
             .sort_index())

# aplanar MultiIndex de columnas
out_daily.columns = [f"{m}__{kw}" for m,kw in out_daily.columns]
out_daily = out_daily.reset_index().rename(columns={"date":"Date"})

# Exportar
daily_path_csv = PROC_NEWS_DIR / "news_sentiment_daily.csv"
daily_path_parq = PROC_NEWS_DIR / "news_sentiment_daily.parquet"
out_daily.to_csv(daily_path_csv, index=False)
out_daily.to_parquet(daily_path_parq, index=False)

daily_path_csv, daily_path_parq

# %%
df["week"] = pd.to_datetime(df["date"]) - pd.to_timedelta(pd.to_datetime(df["date"]).dt.weekday, unit="D")
df["month"] = pd.to_datetime(df["date"]).values.astype("datetime64[M]")

def agg_period(period_col):
    tmp = (df.groupby([period_col,"_kw"])
             .agg(n=("url","count"),
                  pos=("sent_label", lambda s: (s=="POS").sum()),
                  neg=("sent_label", lambda s: (s=="NEG").sum()),
                  neu=("sent_label", lambda s: (s=="NEU").sum()),
                  sent_mean=("sent_num","mean"))
             .reset_index())
    out = (tmp.pivot(index=period_col, columns="_kw", values=["n","pos","neg","neu","sent_mean"])
              .sort_index())
    out.columns = [f"{m}__{kw}" for m,kw in out.columns]
    out = out.reset_index().rename(columns={period_col:"Date"})
    return out

weekly = agg_period("week")
monthly = agg_period("month")

weekly.to_csv(PROC_NEWS_DIR / "news_sentiment_weekly.csv", index=False)
monthly.to_csv(PROC_NEWS_DIR / "news_sentiment_monthly.csv", index=False)

weekly.head(), monthly.head()

# %%
import matplotlib.pyplot as plt

cols_bbva = [c for c in out_daily.columns if "__" in c and "BBVA" in c]
cols_san  = [c for c in out_daily.columns if "__" in c and "Santander" in c]

plt.figure(figsize=(12,5))
plt.plot(out_daily["Date"], out_daily["sent_mean__\"BBVA\" OR \"Banco Bilbao Vizcaya Argentaria\" OR BBVA.MC"], label="Sent diario · BBVA")
plt.plot(out_daily["Date"], out_daily["sent_mean__\"Banco Santander\" OR \"Santander\" OR SAN.MC"], label="Sent diario · SAN")
plt.title("Sentimiento medio diario (titulares) · 2000–2025")
plt.xlabel("Fecha"); plt.ylabel("sent_mean (-1..1)")
plt.legend(); plt.grid(True, linestyle="--", alpha=0.5)
plt.tight_layout()
plt.show()

# %%
precios_bbva = pd.read_csv("../data/BBVA.csv", parse_dates=["Date"])
precios_san  = pd.read_csv("../data/SANTANDER.csv", parse_dates=["Date"])

sent_daily = pd.read_csv(PROC_NEWS_DIR / "news_sentiment_daily.csv", parse_dates=["Date"])

# Merge (alineamos por Date)
m_bbva = precios_bbva.merge(sent_daily[["Date","sent_mean__\"BBVA\" OR \"Banco Bilbao Vizcaya Argentaria\" OR BBVA.MC",
                                        "n__\"BBVA\" OR \"Banco Bilbao Vizcaya Argentaria\" OR BBVA.MC"]],
                            on="Date", how="left")

m_san  = precios_san.merge(sent_daily[["Date","sent_mean__\"Banco Santander\" OR \"Santander\" OR SAN.MC",
                                       "n__\"Banco Santander\" OR \"Santander\" OR SAN.MC"]],
                           on="Date", how="left")

m_bbva.head(), m_san.head()
